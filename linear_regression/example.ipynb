# %% [markdown]
# In this notebook :
# - Generate synthetic data.
# - Train a custom Linear Regression model implemented from scratch.
# - Visualize the fitted regression line.
# - Plot the cost function over iterations.
# - Compare results with scikit-learn.

# %%
import numpy as np
